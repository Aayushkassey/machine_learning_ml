# %% [markdown]
# #List

# %% [markdown]
# .Creating List<br>
# .literals(Using Brackets)<br>
# .list() constructor

# %%
numbers=[1,2,3,4,5] #list

# %% [markdown]
# ###Acessing item in list

# %%
print(numbers[0])
# Out:
# 1

# %%
print(numbers[-1])
# Out:
# 5

# %% [markdown]
# ###Methods

# %% [markdown]
# .append()<br>
# .remove()<br>
# .sort()
# etc

# %%
numbers.append(6)
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numbers.remove(2)
print(numbers)
# Out:
# [1, 3, 4, 5, 6]

# %%
unsorted=[9,3,5,2,1]
unsorted.sort()
print(unsorted)
# Out:
# [1, 2, 3, 5, 9]

# %% [markdown]
# ###List Comprehension

# %%
even= [num for num in range(0,10) if num % 2 == 0]
print(even)
# Out:
# [0, 2, 4, 6, 8]

# %%
square=[num**2 for num in range(0,10)]
print(square)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# #Dictionary

# %% [markdown]
# .Mutable cells<br>
# .contain unique key<br>
# .camn contain list as values

# %% [markdown]
# ###Creating Dictionary

# %%
color={1:"red", 2:"blue", 3:"green"}

# %%
color={'rojo':"red", 2:'5', 3:'green'}

# %% [markdown]
# ###Acessing value from dictionary

# %%
color['rojo']
# Out:
# 'red'

# %%
color[2]
# Out:
# '5'

# %% [markdown]
# ###Updating Value

# %%
color[2]=10

# %%
color={'rojo':"red", 2:10, 3:'green'}

# %%
random={1:"red", 2:10, 3:['black','white']}

# %%
random[2]
# Out:
# 10

# %%
random[3]
# Out:
# ['black', 'white']

# %%
random[3][1]
# Out:
# 'white'

# %%
random[3][0]
# Out:
# 'black'

# %% [markdown]
# #Tuple

# %% [markdown]
# .immutable sequence of values<br>
# .heterogenous<br>
#
# where it is used <br>
# .when items need to be unchangeable

# %% [markdown]
# ###Creating Tuple

# %%
color=(255,255,255) #white
color=(0,0,0) #black

# %% [markdown]
# ###Accessing Tuple using INdex

# %%
color[2]
# Out:
# 255

# %%
color=(100,200,255)

# %%
color[1] #[0,1,2]#index value
# Out:
# 200

# %% [markdown]
# #Set

# %% [markdown]
# same like mathematics <br>
# union,disjoint

# %% [markdown]
# ###Creating Set

# %%
random=[1,2,3]

# %%
set(random)
# Out:
# {1, 2, 3}

# %%
random=[1,2,2,3,4,4,4,5]

# %%
set(random)  #set le same number lai ignore gareyra yautai ma display garxa
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ###Pass String

# %% [markdown]
# The order is not presented in set<br>
# String is iterable

# %%
name='Ram'
set(name)
# Out:
# {'R', 'a', 'm'}

# %%
name="Harry"
set(name)
# Out:
# {'H', 'a', 'r', 'y'}

# %%
name="Harryh"
set(name)
# Out:
# {'H', 'a', 'h', 'r', 'y'}

# %%
color="red"
color_set=set(color)

# %%
name="Harryh"
name_set=set(name)

# %%
#union operation
print(color_set|name_set)
# Out:
# {'y', 'e', 'H', 'h', 'a', 'd', 'r'}

# %% [markdown]
# # Data Types

# %% [markdown]
# ### 1) int

# %%
b=5
print(b)
# Out:
# 5

# %%
b=5
type(b)  #type le data kun type ho vaneyra declare garxa
# Out:
# int

# %% [markdown]
# ### 2) float

# %%
b=3.14
type (b)
# Out:
# float

# %% [markdown]
# ### 3) str

# %%
name="ram"
type(name)
# Out:
# str

# %% [markdown]
# ### 4) Bool

# %%
x= True
type(x)
# Out:
# bool
